# %% [markdown]
# <a href="https://colab.research.google.com/github/TungIT2912/Distributed_Task_Queue/blob/main/slides/lab-00-introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 00 - Introduction
#
# - **It is absolutely recommended to read the documentation relating to the functions and methods used!**
#     - Usually, it is sufficient type on Google the name of the function (and eventually the name of the library used)
# - **The usage of ChatGPT and generative AI tools is highly discouraged during the labs**
#     - You must train the fundamentals before using advanced models
#     - When you start driving, you do not start with a F1 race car!
#     - At the exam, you must be capable to explain all the details of your assignment

# %% [markdown]
# ## Goal of the lab: a first example of data preprocessing
#
# Data is usually stored in (textual) files
#
# - Usually, files cannot be directly handled by machine-learning approaches
# - We need to upload them in the notebook and transform them to apply further analysis
#
# How do we load existing datasets?
#
# What data structures do you know in Python?

# %% [markdown]
# ## File format: CSV
#
# Comma-separated values (CSV)
#
# - CSV is a text file format that uses commas to separate values, and newlines to separate records
# - A CSV file stores tabular data (numbers and text) in plain text, where each line of the file typically represents one data record
# - Each record consists of the same number of fields
# - If the field delimiter itself may appear within a field, fields can be surrounded with quotation marks.

# %% [markdown]
# ## Locating the data
#
# These are main options to use files/datasets in a Colab project:
#
# 1. Use the existing data in the `/content/sample_data/` folder
# 2. Upload a new dataset (as file)
#   - Upload the file through the Colab GUI (temporary upload!);
#   - Upload the file on your Google Drive (you have to use the same Google account that you use with Colab)). Then, it is necessary to mount the drive in your Colab machine (use the "Mount Drive" button.);
#   - Use the following code snippet, file are uploaded to `/content/<file_name>`
# 3. Use existing datasets from the web

# %% [markdown]
# ## Read the existing data
#
# `open(<path>, <mode>)`: open the file located in the `path`, for reading, writing, ect. depending by the `mode`.

# %%
file_path = '/content/sample_data/california_housing_train.csv'
with open(file_path, 'r') as f:
    lines = f.readlines()
print('Read {} lines'.format(len(lines)))
# Out:
# Read 17001 lines

# %% [markdown]
# ## Upload new data

# %%
from google.colab import files
# uploaded = files.upload()  # uncomment this line to open the prompt to upload the dataset

# %% [markdown]
# ## Import data from the web

# %%
# !rm -rf iris/ || true # remove the folder if exists
# !rm iris.zip || true # remove the zip file if exists
# !wget https://archive.ics.uci.edu/static/public/53/iris.zip # download the public dataset
# !unzip iris.zip -d iris # unzip it

file_path = '/content/iris/iris.data'
with open(file_path, 'r') as f:
    lines = f.readlines()
print('Read {} lines'.format(len(lines)))
# Out:
# rm: cannot remove 'iris.zip': No such file or directory
# --2025-11-26 12:26:16--  https://archive.ics.uci.edu/static/public/53/iris.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘iris.zip’
#
# iris.zip                [ <=>                ]   3.65K  --.-KB/s    in 0s
#
# 2025-11-26 12:26:17 (440 MB/s) - ‘iris.zip’ saved [3738]
#
# Archive:  iris.zip
#   inflating: iris/Index
#   inflating: iris/bezdekIris.data
#   inflating: iris/iris.data
#   inflating: iris/iris.names
# Read 151 lines

# %% [markdown]
# ## Strings and lists
#
# Tools for managing strings and lists:
#
# - `strip()`: removes both the leading and the trailing characters.
# - `split()`: breaks up a string at the specified separator and returns a list of strings.
# - List slicing: `list[start:stop:step]`
#
# Examples:
#
# *   `a[start:stop]  # items start through stop-1`
# *   `a[start:]      # items start through the rest of the array`
# *   `a[:stop]       # items from the beginning through stop-1`
# *   `a[:]           # a copy of the whole array`
# *   `a[-1]    # last item in the array`
# *   `a[-2:]   # last two items in the array`
# *   `a[:-2]   # everything except the last two items`
# *    `a[::-1]    # all items in the array, reversed`

# %%
lines[:5]
# Out:
# ['5.1,3.5,1.4,0.2,Iris-setosa\n',
#  '4.9,3.0,1.4,0.2,Iris-setosa\n',
#  '4.7,3.2,1.3,0.2,Iris-setosa\n',
#  '4.6,3.1,1.5,0.2,Iris-setosa\n',
#  '5.0,3.6,1.4,0.2,Iris-setosa\n']

# %%
for line in lines[:2]:
    print("Raw content:", line)
    content = line.strip()
    print("Content after strip:", content)
    content = content.split(',')
    print("Content after split:", content)
    # now the content is a list with the splitted elements
    data = content[:-2]   # the image name is in the first position
    label = content[-1] # coordinates in the following part
    # print the content
    print('Data:', data, 'Label:', label)
    print('---')
# Out:
# Raw content: 5.1,3.5,1.4,0.2,Iris-setosa
#
# Content after strip: 5.1,3.5,1.4,0.2,Iris-setosa
# Content after split: ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# Data: ['5.1', '3.5', '1.4'] Label: Iris-setosa
# ---
# Raw content: 4.9,3.0,1.4,0.2,Iris-setosa
#
# Content after strip: 4.9,3.0,1.4,0.2,Iris-setosa
# Content after split: ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# Data: ['4.9', '3.0', '1.4'] Label: Iris-setosa
# ---

# %% [markdown]
# ## Changing data types
#
# Note that the element in the list are strings. We must convert these strings in integers (`int`). These integers are then saved in a list.
#
# **Tools**:
# - List comprehension: `[expression for item in list]`

# %%
print('Type of the data:', type(data[0]))
data = [float(x) for x in data]
print('Type of the data:', [type(x) for x in data])
data
# Out:
# Type of the data: <class 'str'>
# Type of the data: [<class 'float'>, <class 'float'>, <class 'float'>]
# [4.9, 3.0, 1.4]

# %% [markdown]
# ## Exercise
#
# 1. Read the content of the file `iris.data`
# 1. **Accumulate** the data and the labels in two different lists, named `dataset` and `labels`
# 1. Cast all data to float
# 1. Output the final length of the two lists.
#
# Given the input file with content
#
#     5.1,3.5,1.4,0.2,Iris-setosa
#     4.9,3.0,1.4,0.2,Iris-setosa
#     ...
#
# The lists should look like
#
# ```python
# dataset = [[5.1,3.5,1.4,0.2], [4.9,3.0,1.4,0.2], ...]
# labels = ['Iris-setosa', 'Iris-setosa', ...]
# ```

# %%
# write the code here
file_path = '/content/iris/iris.data'

dataset = []
labels = []
with open(file_path, 'r') as f:
    lines = f.readlines()


for line in lines:
    print("line",line)
    line = line.strip()
    if not line:
        continue
    parts = line.split(',')
    data = parts[:-1]
    label = parts[-1]
    data = [float(x) for x in data]
    dataset.append(data)
    labels.append(label)
print('Type of the data:', [type(x) for x in data])
print("dataset:", dataset)
print("labels:", labels)
# Out:
# lines 5.1,3.5,1.4,0.2,Iris-setosa
#
# lines 4.9,3.0,1.4,0.2,Iris-setosa
#
# lines 4.7,3.2,1.3,0.2,Iris-setosa
#
# lines 4.6,3.1,1.5,0.2,Iris-setosa
#
# lines 5.0,3.6,1.4,0.2,Iris-setosa
#
# lines 5.4,3.9,1.7,0.4,Iris-setosa
#
# lines 4.6,3.4,1.4,0.3,Iris-setosa
#
# lines 5.0,3.4,1.5,0.2,Iris-setosa
#
# lines 4.4,2.9,1.4,0.2,Iris-setosa
#
# lines 4.9,3.1,1.5,0.1,Iris-setosa
#
# lines 5.4,3.7,1.5,0.2,Iris-setosa
#
# lines 4.8,3.4,1.6,0.2,Iris-setosa
#
# lines 4.8,3.0,1.4,0.1,Iris-setosa
#
# lines 4.3,3.0,1.1,0.1,Iris-setosa
#
# lines 5.8,4.0,1.2,0.2,Iris-setosa
#
# lines 5.7,4.4,1.5,0.4,Iris-setosa
#
# lines 5.4,3.9,1.3,0.4,Iris-setosa
#
# lines 5.1,3.5,1.4,0.3,Iris-setosa
#
# lines 5.7,3.8,1.7,0.3,Iris-setosa
#
# lines 5.1,3.8,1.5,0.3,Iris-setosa
#
# lines 5.4,3.4,1.7,0.2,Iris-setosa
#
# lines 5.1,3.7,1.5,0.4,Iris-setosa
#
# lines 4.6,3.6,1.0,0.2,Iris-setosa
#
# lines 5.1,3.3,1.7,0.5,Iris-setosa
#
# lines 4.8,3.4,1.9,0.2,Iris-setosa
#
# lines 5.0,3.0,1.6,0.2,Iris-setosa
#
# lines 5.0,3.4,1.6,0.4,Iris-setosa
#
# lines 5.2,3.5,1.5,0.2,Iris-setosa
#
# lines 5.2,3.4,1.4,0.2,Iris-setosa
#
# lines 4.7,3.2,1.6,0.2,Iris-setosa
#
# lines 4.8,3.1,1.6,0.2,Iris-setosa
#
# lines 5.4,3.4,1.5,0.4,Iris-setosa
#
# lines 5.2,4.1,1.5,0.1,Iris-setosa
#
# lines 5.5,4.2,1.4,0.2,Iris-setosa
#
# lines 4.9,3.1,1.5,0.1,Iris-setosa
#
# lines 5.0,3.2,1.2,0.2,Iris-setosa
#
# lines 5.5,3.5,1.3,0.2,Iris-setosa
#
# lines 4.9,3.1,1.5,0.1,Iris-setosa
#
# lines 4.4,3.0,1.3,0.2,Iris-setosa
#
# lines 5.1,3.4,1.5,0.2,Iris-setosa
#
# lines 5.0,3.5,1.3,0.3,Iris-setosa
#
# lines 4.5,2.3,1.3,0.3,Iris-setosa
#
# lines 4.4,3.2,1.3,0.2,Iris-setosa
#
# lines 5.0,3.5,1.6,0.6,Iris-setosa
#
# lines 5.1,3.8,1.9,0.4,Iris-setosa
#
# lines 4.8,3.0,1.4,0.3,Iris-setosa
#
# lines 5.1,3.8,1.6,0.2,Iris-setosa
#
# lines 4.6,3.2,1.4,0.2,Iris-setosa
#
# lines 5.3,3.7,1.5,0.2,Iris-setosa
#
# lines 5.0,3.3,1.4,0.2,Iris-setosa
#
# lines 7.0,3.2,4.7,1.4,Iris-versicolor
#
# lines 6.4,3.2,4.5,1.5,Iris-versicolor
#
# lines 6.9,3.1,4.9,1.5,Iris-versicolor
#
# lines 5.5,2.3,4.0,1.3,Iris-versicolor
#
# lines 6.5,2.8,4.6,1.5,Iris-versicolor
#
# lines 5.7,2.8,4.5,1.3,Iris-versicolor
#
# lines 6.3,3.3,4.7,1.6,Iris-versicolor
#
# lines 4.9,2.4,3.3,1.0,Iris-versicolor
#
# lines 6.6,2.9,4.6,1.3,Iris-versicolor
#
# lines 5.2,2.7,3.9,1.4,Iris-versicolor
#
# lines 5.0,2.0,3.5,1.0,Iris-versicolor
#
# lines 5.9,3.0,4.2,1.5,Iris-versicolor
#
# lines 6.0,2.2,4.0,1.0,Iris-versicolor
#
# lines 6.1,2.9,4.7,1.4,Iris-versicolor
#
# lines 5.6,2.9,3.6,1.3,Iris-versicolor
#
# lines 6.7,3.1,4.4,1.4,Iris-versicolor
#
# lines 5.6,3.0,4.5,1.5,Iris-versicolor
#
# lines 5.8,2.7,4.1,1.0,Iris-versicolor
#
# lines 6.2,2.2,4.5,1.5,Iris-versicolor
#
# lines 5.6,2.5,3.9,1.1,Iris-versicolor
#
# lines 5.9,3.2,4.8,1.8,Iris-versicolor
#
# lines 6.1,2.8,4.0,1.3,Iris-versicolor
#
# lines 6.3,2.5,4.9,1.5,Iris-versicolor
#
# lines 6.1,2.8,4.7,1.2,Iris-versicolor
#
# lines 6.4,2.9,4.3,1.3,Iris-versicolor
#
# lines 6.6,3.0,4.4,1.4,Iris-versicolor
#
# lines 6.8,2.8,4.8,1.4,Iris-versicolor
#
# lines 6.7,3.0,5.0,1.7,Iris-versicolor
#
# lines 6.0,2.9,4.5,1.5,Iris-versicolor
#
# lines 5.7,2.6,3.5,1.0,Iris-versicolor
#
# lines 5.5,2.4,3.8,1.1,Iris-versicolor
#
# lines 5.5,2.4,3.7,1.0,Iris-versicolor
#
# lines 5.8,2.7,3.9,1.2,Iris-versicolor
#
# lines 6.0,2.7,5.1,1.6,Iris-versicolor
#
# lines 5.4,3.0,4.5,1.5,Iris-versicolor
#
# lines 6.0,3.4,4.5,1.6,Iris-versicolor
#
# lines 6.7,3.1,4.7,1.5,Iris-versicolor
#
# lines 6.3,2.3,4.4,1.3,Iris-versicolor
#
# lines 5.6,3.0,4.1,1.3,Iris-versicolor
#
# lines 5.5,2.5,4.0,1.3,Iris-versicolor
#
# lines 5.5,2.6,4.4,1.2,Iris-versicolor
#
# lines 6.1,3.0,4.6,1.4,Iris-versicolor
#
# lines 5.8,2.6,4.0,1.2,Iris-versicolor
#
# lines 5.0,2.3,3.3,1.0,Iris-versicolor
#
# lines 5.6,2.7,4.2,1.3,Iris-versicolor
#
# lines 5.7,3.0,4.2,1.2,Iris-versicolor
#
# lines 5.7,2.9,4.2,1.3,Iris-versicolor
#
# lines 6.2,2.9,4.3,1.3,Iris-versicolor
#
# lines 5.1,2.5,3.0,1.1,Iris-versicolor
#
# lines 5.7,2.8,4.1,1.3,Iris-versicolor
#
# lines 6.3,3.3,6.0,2.5,Iris-virginica
#
# lines 5.8,2.7,5.1,1.9,Iris-virginica
#
# lines 7.1,3.0,5.9,2.1,Iris-virginica
#
# lines 6.3,2.9,5.6,1.8,Iris-virginica
#
# lines 6.5,3.0,5.8,2.2,Iris-virginica
#
# lines 7.6,3.0,6.6,2.1,Iris-virginica
#
# lines 4.9,2.5,4.5,1.7,Iris-virginica
#
# lines 7.3,2.9,6.3,1.8,Iris-virginica
#
# lines 6.7,2.5,5.8,1.8,Iris-virginica
#
# lines 7.2,3.6,6.1,2.5,Iris-virginica
#
# lines 6.5,3.2,5.1,2.0,Iris-virginica
#
# lines 6.4,2.7,5.3,1.9,Iris-virginica
#
# lines 6.8,3.0,5.5,2.1,Iris-virginica
#
# lines 5.7,2.5,5.0,2.0,Iris-virginica
#
# lines 5.8,2.8,5.1,2.4,Iris-virginica
#
# lines 6.4,3.2,5.3,2.3,Iris-virginica
#
# lines 6.5,3.0,5.5,1.8,Iris-virginica
#
# lines 7.7,3.8,6.7,2.2,Iris-virginica
#
# lines 7.7,2.6,6.9,2.3,Iris-virginica
#
# lines 6.0,2.2,5.0,1.5,Iris-virginica
#
# lines 6.9,3.2,5.7,2.3,Iris-virginica
#
# lines 5.6,2.8,4.9,2.0,Iris-virginica
#
# lines 7.7,2.8,6.7,2.0,Iris-virginica
#
# lines 6.3,2.7,4.9,1.8,Iris-virginica
#
# lines 6.7,3.3,5.7,2.1,Iris-virginica
#
# lines 7.2,3.2,6.0,1.8,Iris-virginica
#
# lines 6.2,2.8,4.8,1.8,Iris-virginica
#
# lines 6.1,3.0,4.9,1.8,Iris-virginica
#
# lines 6.4,2.8,5.6,2.1,Iris-virginica
#
# lines 7.2,3.0,5.8,1.6,Iris-virginica
#
# lines 7.4,2.8,6.1,1.9,Iris-virginica
#
# lines 7.9,3.8,6.4,2.0,Iris-virginica
#
# lines 6.4,2.8,5.6,2.2,Iris-virginica
#
# lines 6.3,2.8,5.1,1.5,Iris-virginica
#
# lines 6.1,2.6,5.6,1.4,Iris-virginica
#
# lines 7.7,3.0,6.1,2.3,Iris-virginica
#
# lines 6.3,3.4,5.6,2.4,Iris-virginica
#
# lines 6.4,3.1,5.5,1.8,Iris-virginica
#
# lines 6.0,3.0,4.8,1.8,Iris-virginica
#
# lines 6.9,3.1,5.4,2.1,Iris-virginica
#
# lines 6.7,3.1,5.6,2.4,Iris-virginica
#
# lines 6.9,3.1,5.1,2.3,Iris-virginica
#
# lines 5.8,2.7,5.1,1.9,Iris-virginica
#
# lines 6.8,3.2,5.9,2.3,Iris-virginica
#
# lines 6.7,3.3,5.7,2.5,Iris-virginica
#
# lines 6.7,3.0,5.2,2.3,Iris-virginica
#
# lines 6.3,2.5,5.0,1.9,Iris-virginica
#
# lines 6.5,3.0,5.2,2.0,Iris-virginica
#
# lines 6.2,3.4,5.4,2.3,Iris-virginica
#
# lines 5.9,3.0,5.1,1.8,Iris-virginica
#
# lines
#
# Type of the data: [<class 'float'>, <class 'float'>, <class 'float'>, <class 'float'
['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica']

# %%
file_path = '/content/iris/iris.data'

dataset = []
labels = []
with open(file_path, 'r') as f:
    lines = f.readlines()


for line in lines:
    print("line",line)
    line = line.strip()
    if not line:
        continue
    parts = line.split(',')
    data = parts[:-1]
    label = parts[-1]
    data = [float(x) for x in data]
    dataset.append(data)
    labels.append(label)
print('Type of the data:', [type(x) for x in data])
print("dataset:", dataset)
print("labels:", labels)
# Out:
# line 5.1,3.5,1.4,0.2,Iris-setosa
#
# line 4.9,3.0,1.4,0.2,Iris-setosa
#
# line 4.7,3.2,1.3,0.2,Iris-setosa
#
# line 4.6,3.1,1.5,0.2,Iris-setosa
#
# line 5.0,3.6,1.4,0.2,Iris-setosa
#
# line 5.4,3.9,1.7,0.4,Iris-setosa
#
# line 4.6,3.4,1.4,0.3,Iris-setosa
#
# line 5.0,3.4,1.5,0.2,Iris-setosa
#
# line 4.4,2.9,1.4,0.2,Iris-setosa
#
# line 4.9,3.1,1.5,0.1,Iris-setosa
#
# line 5.4,3.7,1.5,0.2,Iris-setosa
#
# line 4.8,3.4,1.6,0.2,Iris-setosa
#
# line 4.8,3.0,1.4,0.1,Iris-setosa
#
# line 4.3,3.0,1.1,0.1,Iris-setosa
#
# line 5.8,4.0,1.2,0.2,Iris-setosa
#
# line 5.7,4.4,1.5,0.4,Iris-setosa
#
# line 5.4,3.9,1.3,0.4,Iris-setosa
#
# line 5.1,3.5,1.4,0.3,Iris-setosa
#
# line 5.7,3.8,1.7,0.3,Iris-setosa
#
# line 5.1,3.8,1.5,0.3,Iris-setosa
#
# line 5.4,3.4,1.7,0.2,Iris-setosa
#
# line 5.1,3.7,1.5,0.4,Iris-setosa
#
# line 4.6,3.6,1.0,0.2,Iris-setosa
#
# line 5.1,3.3,1.7,0.5,Iris-setosa
#
# line 4.8,3.4,1.9,0.2,Iris-setosa
#
# line 5.0,3.0,1.6,0.2,Iris-setosa
#
# line 5.0,3.4,1.6,0.4,Iris-setosa
#
# line 5.2,3.5,1.5,0.2,Iris-setosa
#
# line 5.2,3.4,1.4,0.2,Iris-setosa
#
# line 4.7,3.2,1.6,0.2,Iris-setosa
#
# line 4.8,3.1,1.6,0.2,Iris-setosa
#
# line 5.4,3.4,1.5,0.4,Iris-setosa
#
# line 5.2,4.1,1.5,0.1,Iris-setosa
#
# line 5.5,4.2,1.4,0.2,Iris-setosa
#
# line 4.9,3.1,1.5,0.1,Iris-setosa
#
# line 5.0,3.2,1.2,0.2,Iris-setosa
#
# line 5.5,3.5,1.3,0.2,Iris-setosa
#
# line 4.9,3.1,1.5,0.1,Iris-setosa
#
# line 4.4,3.0,1.3,0.2,Iris-setosa
#
# line 5.1,3.4,1.5,0.2,Iris-setosa
#
# line 5.0,3.5,1.3,0.3,Iris-setosa
#
# line 4.5,2.3,1.3,0.3,Iris-setosa
#
# line 4.4,3.2,1.3,0.2,Iris-setosa
#
# line 5.0,3.5,1.6,0.6,Iris-setosa
#
# line 5.1,3.8,1.9,0.4,Iris-setosa
#
# line 4.8,3.0,1.4,0.3,Iris-setosa
#
# line 5.1,3.8,1.6,0.2,Iris-setosa
#
# line 4.6,3.2,1.4,0.2,Iris-setosa
#
# line 5.3,3.7,1.5,0.2,Iris-setosa
#
# line 5.0,3.3,1.4,0.2,Iris-setosa
#
# line 7.0,3.2,4.7,1.4,Iris-versicolor
#
# line 6.4,3.2,4.5,1.5,Iris-versicolor
#
# line 6.9,3.1,4.9,1.5,Iris-versicolor
#
# line 5.5,2.3,4.0,1.3,Iris-versicolor
#
# line 6.5,2.8,4.6,1.5,Iris-versicolor
#
# line 5.7,2.8,4.5,1.3,Iris-versicolor
#
# line 6.3,3.3,4.7,1.6,Iris-versicolor
#
# line 4.9,2.4,3.3,1.0,Iris-versicolor
#
# line 6.6,2.9,4.6,1.3,Iris-versicolor
#
# line 5.2,2.7,3.9,1.4,Iris-versicolor
#
# line 5.0,2.0,3.5,1.0,Iris-versicolor
#
# line 5.9,3.0,4.2,1.5,Iris-versicolor
#
# line 6.0,2.2,4.0,1.0,Iris-versicolor
#
# line 6.1,2.9,4.7,1.4,Iris-versicolor
#
# line 5.6,2.9,3.6,1.3,Iris-versicolor
#
# line 6.7,3.1,4.4,1.4,Iris-versicolor
#
# line 5.6,3.0,4.5,1.5,Iris-versicolor
#
# line 5.8,2.7,4.1,1.0,Iris-versicolor
#
# line 6.2,2.2,4.5,1.5,Iris-versicolor
#
# line 5.6,2.5,3.9,1.1,Iris-versicolor
#
# line 5.9,3.2,4.8,1.8,Iris-versicolor
#
# line 6.1,2.8,4.0,1.3,Iris-versicolor
#
# line 6.3,2.5,4.9,1.5,Iris-versicolor
#
# line 6.1,2.8,4.7,1.2,Iris-versicolor
#
# line 6.4,2.9,4.3,1.3,Iris-versicolor
#
# line 6.6,3.0,4.4,1.4,Iris-versicolor
#
# line 6.8,2.8,4.8,1.4,Iris-versicolor
#
# line 6.7,3.0,5.0,1.7,Iris-versicolor
#
# line 6.0,2.9,4.5,1.5,Iris-versicolor
#
# line 5.7,2.6,3.5,1.0,Iris-versicolor
#
# line 5.5,2.4,3.8,1.1,Iris-versicolor
#
# line 5.5,2.4,3.7,1.0,Iris-versicolor
#
# line 5.8,2.7,3.9,1.2,Iris-versicolor
#
# line 6.0,2.7,5.1,1.6,Iris-versicolor
#
# line 5.4,3.0,4.5,1.5,Iris-versicolor
#
# line 6.0,3.4,4.5,1.6,Iris-versicolor
#
# line 6.7,3.1,4.7,1.5,Iris-versicolor
#
# line 6.3,2.3,4.4,1.3,Iris-versicolor
#
# line 5.6,3.0,4.1,1.3,Iris-versicolor
#
# line 5.5,2.5,4.0,1.3,Iris-versicolor
#
# line 5.5,2.6,4.4,1.2,Iris-versicolor
#
# line 6.1,3.0,4.6,1.4,Iris-versicolor
#
# line 5.8,2.6,4.0,1.2,Iris-versicolor
#
# line 5.0,2.3,3.3,1.0,Iris-versicolor
#
# line 5.6,2.7,4.2,1.3,Iris-versicolor
#
# line 5.7,3.0,4.2,1.2,Iris-versicolor
#
# line 5.7,2.9,4.2,1.3,Iris-versicolor
#
# line 6.2,2.9,4.3,1.3,Iris-versicolor
#
# line 5.1,2.5,3.0,1.1,Iris-versicolor
#
# line 5.7,2.8,4.1,1.3,Iris-versicolor
#
# line 6.3,3.3,6.0,2.5,Iris-virginica
#
# line 5.8,2.7,5.1,1.9,Iris-virginica
#
# line 7.1,3.0,5.9,2.1,Iris-virginica
#
# line 6.3,2.9,5.6,1.8,Iris-virginica
#
# line 6.5,3.0,5.8,2.2,Iris-virginica
#
# line 7.6,3.0,6.6,2.1,Iris-virginica
#
# line 4.9,2.5,4.5,1.7,Iris-virginica
#
# line 7.3,2.9,6.3,1.8,Iris-virginica
#
# line 6.7,2.5,5.8,1.8,Iris-virginica
#
# line 7.2,3.6,6.1,2.5,Iris-virginica
#
# line 6.5,3.2,5.1,2.0,Iris-virginica
#
# line 6.4,2.7,5.3,1.9,Iris-virginica
#
# line 6.8,3.0,5.5,2.1,Iris-virginica
#
# line 5.7,2.5,5.0,2.0,Iris-virginica
#
# line 5.8,2.8,5.1,2.4,Iris-virginica
#
# line 6.4,3.2,5.3,2.3,Iris-virginica
#
# line 6.5,3.0,5.5,1.8,Iris-virginica
#
# line 7.7,3.8,6.7,2.2,Iris-virginica
#
# line 7.7,2.6,6.9,2.3,Iris-virginica
#
# line 6.0,2.2,5.0,1.5,Iris-virginica
#
# line 6.9,3.2,5.7,2.3,Iris-virginica
#
# line 5.6,2.8,4.9,2.0,Iris-virginica
#
# line 7.7,2.8,6.7,2.0,Iris-virginica
#
# line 6.3,2.7,4.9,1.8,Iris-virginica
#
# line 6.7,3.3,5.7,2.1,Iris-virginica
#
# line 7.2,3.2,6.0,1.8,Iris-virginica
#
# line 6.2,2.8,4.8,1.8,Iris-virginica
#
# line 6.1,3.0,4.9,1.8,Iris-virginica
#
# line 6.4,2.8,5.6,2.1,Iris-virginica
#
# line 7.2,3.0,5.8,1.6,Iris-virginica
#
# line 7.4,2.8,6.1,1.9,Iris-virginica
#
# line 7.9,3.8,6.4,2.0,Iris-virginica
#
# line 6.4,2.8,5.6,2.2,Iris-virginica
#
# line 6.3,2.8,5.1,1.5,Iris-virginica
#
# line 6.1,2.6,5.6,1.4,Iris-virginica
#
# line 7.7,3.0,6.1,2.3,Iris-virginica
#
# line 6.3,3.4,5.6,2.4,Iris-virginica
#
# line 6.4,3.1,5.5,1.8,Iris-virginica
#
# line 6.0,3.0,4.8,1.8,Iris-virginica
#
# line 6.9,3.1,5.4,2.1,Iris-virginica
#
# line 6.7,3.1,5.6,2.4,Iris-virginica
#
# line 6.9,3.1,5.1,2.3,Iris-virginica
#
# line 5.8,2.7,5.1,1.9,Iris-virginica
#
# line 6.8,3.2,5.9,2.3,Iris-virginica
#
# line 6.7,3.3,5.7,2.5,Iris-virginica
#
# line 6.7,3.0,5.2,2.3,Iris-virginica
#
# line 6.3,2.5,5.0,1.9,Iris-virginica
#
# line 6.5,3.0,5.2,2.0,Iris-virginica
#
# line 6.2,3.4,5.4,2.3,Iris-virginica
#
# line 5.9,3.0,5.1,1.8,Iris-virginica
#
# line
#
# Type of the data: [<class 'float'>, <class 'float'>, <class 'float'>, <class 'float'